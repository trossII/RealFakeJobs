# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

# %%
data = pd.read_csv('../Downloads/fake_job_postings.csv')

# %%
data.describe()
# Out:
#              job_id  telecommuting  has_company_logo  has_questions  \
# count  17880.000000   17880.000000      17880.000000   17880.000000
# mean    8940.500000       0.042897          0.795302       0.491723
# std     5161.655742       0.202631          0.403492       0.499945
# min        1.000000       0.000000          0.000000       0.000000
# 25%     4470.750000       0.000000          1.000000       0.000000
# 50%     8940.500000       0.000000          1.000000       0.000000
# 75%    13410.250000       0.000000          1.000000       1.000000
# max    17880.000000       1.000000          1.000000       1.000000
#
#          fraudulent
# count  17880.000000
# mean       0.048434
# std        0.214688
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
data.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %% [markdown]
# #From what I can see and know about my current data is that:
# - The fraudulent feature will be what I am basing my training off and scoring off of
# - I will need to do some type of text processing on most of the features including but not limited to the company_profile, description and requirements
#
# #What I need to figure out
# - Metric to base scoring off of
# - What I should do with the NaNs
# - Can/should I group any variables before machine learning
# - What would be my best option for word processing

# %%
stopwords_list = stopwords.words('english') + list(string.punctuation)
vectorizer = TfidfVectorizer(strip_accents='unicode',stop_words=stopwords_list)

# %%
X=data.drop(columns=['job_id','fraudulent'])
y=data['fraudulent']
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y)
Xtrain1,Xval,ytrain1,yval=train_test_split(Xtrain,ytrain)
